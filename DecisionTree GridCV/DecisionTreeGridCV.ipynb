# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
x_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
y_train
# Out:
#           charges
# 1163   2200.83085
# 196    5649.71500
# 438   12592.53450
# 183    7419.47790
# 1298   5261.46945
# ...           ...
# 763    3070.80870
# 835    7160.33030
# 1216   5415.66120
# 559    1646.42970
# 684    4766.02200
#
# [936 rows x 1 columns]

# %%
x_test
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1         1           0
# 610    47  29.370         1         0           0
# 569    48  40.565         2         1           1
# 1034   61  38.380         0         1           0
# 198    51  18.050         0         0           0
# ...   ...     ...       ...       ...         ...
# 1261   28  37.100         1         1           0
# 494    21  25.700         4         1           1
# 97     55  38.280         0         1           0
# 418    64  39.160         1         1           0
# 920    62  25.000         0         0           0
#
# [402 rows x 5 columns]

# %%
y_test
# Out:
#           charges
# 578    9724.53000
# 610    8547.69130
# 569   45702.02235
# 1034  12950.07120
# 198    9644.25250
# ...           ...
# 1261   3277.16100
# 494   17942.10600
# 97    10226.28420
# 418   14418.28040
# 920   13451.12200
#
# [402 rows x 1 columns]

# %%
#Model Creation code for DecisionTreeDT

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid = {'criterion':['squared_error','absolute_error','poisson'],'max_features':['auto','sqrt','log2'],'splitter':['best','random']}

# %%
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True, verbose = 3, n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_

# %%
grid_predictions = grid.predict(x_test)

# %%
#regressor = DecisionTreeRegressor(criterion='friedman_mse',splitter='random',max_features='log2')DT

# %%
#regressor = regressor.fit(x_train,y_train)DT

# %%
#Code to see how the tree is plottedDT

# %%
#import matplotlib.pyplot as pltDT

# %%
#from sklearn import treeDT

# %%
#tree.plot_tree(regressor)DT

# %%
#plt.show()DT

# %%
#y_pred = regressor.predict(x_test)DT

# %%
#Evaluation Metrics

# %%
from sklearn.metrics import r2_score

# %%
r_score = r2_score(y_test, grid_predictions)

# %%
r_score
# Out:
# 0.7691931591160324

# %%
print("The R_Score value for the best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_Score value for the best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'random'}: 0.7691931591160324

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002463      0.001052         0.000000        0.000000
# 1        0.002645      0.000963         0.000000        0.000000
# 2        0.009633      0.002348         0.004440        0.001004
# 3        0.007366      0.001672         0.004108        0.000956
# 4        0.008442      0.000904         0.004419        0.000961
# 5        0.007195      0.000759         0.004607        0.001136
# 6        0.001806      0.000637         0.000000        0.000000
# 7        0.001024      0.000218         0.000000        0.000000
# 8        0.021272      0.003004         0.003542        0.001128
# 9        0.016966      0.002582         0.003576        0.000619
# 10       0.022193      0.001951         0.003176        0.000929
# 11       0.015006      0.002067         0.002699        0.000246
# 12       0.000818      0.000142         0.000000        0.000000
# ...

# %%
age_input = float(input("Age= "))
bmi_input = float(input("Bmi= "))
children_input = float(input("Children= "))
sex_male_input = int(input("Sex Male or not 0 or 1= "))
smoker_yes_input = int(input("Smoker yes or no= "))
# Out:
# Age=  36
# Bmi=  71
# Children=  3
# Sex Male or not 0 or 1=  1
# Smoker yes or no=  1

# %%
Future_predictions = grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

# %%
print("Future_predictions:{}".format(Future_predictions))
# Out:
# Future_predictions:[15555.18875]
