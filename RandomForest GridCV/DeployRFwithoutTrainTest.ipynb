# %%
import pickle

# %%
loaded_model = pickle.load(open("finalized_model_RFwtouttraintest.sav",'rb'))

# %%
age_input = float(input("Age= "))
bmi_input = float(input("BMI= "))
children_input = float(input("Children= "))
sex_male_input = int(input("Male or Female 0 or 1: "))
smoker_input = int(input("Smoker yes or no 0 or 1: "))
# Out:
# Age=  55
# BMI=  76
# Children=  2
# Male or Female 0 or 1:  1
# Smoker yes or no 0 or 1:  1

# %%
Future_Predictions = loaded_model.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_input]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
print("Future Predictions:{}".format(Future_Predictions))
# Out:
# Future Predictions:[47755.75308065]
