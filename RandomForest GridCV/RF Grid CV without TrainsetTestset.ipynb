# %%
import numpy as np

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#from sklearn.model_selection import train_test_split

# %%
#x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30, random_state=0)

# %%
#x_train

# %%
#x_test

# %%
#y_train

# %%
#y_test

# %%
#Model creation in RandomForestRF

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'criterion':['squared_error','absolute_error','poisson'],
'max_features': ['auto','sqrt','log2'],
'n_estimators':[10,100]}

# %%
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)

# %%
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
#regressor=RandomForestRegressor(n_estimators=50, criterion='poisson', random_state=0)RF

# %%
#regressor.fit(x_train,y_train)RF

# %%
#y_pred=regressor.predict(x_test)RF

# %%
#Evaluation MetricsRF

# %%
#from sklearn.metrics import r2_score

# %%
#r_score=r2_score(y_test,y_pred)RF

# %%
#r_scoreRF

# %%
#Saving the best modelRF

# %%
#import pickleRF

# %%
#filename = "finalized_model_RandomForest.sav"RF

# %%
#pickle.dump(regressor, open(filename,'wb'))RF

# %%
re=grid.cv_results_

# %%
grid_predictions = grid.predict(independent)

# %%
from sklearn.metrics import r2_score

# %%
r_score=r2_score(dependent,grid_predictions)

# %%
print("The R-Score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R-Score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}: 0.9683569960253691

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002416      0.000422         0.000000        0.000000
# 1        0.002707      0.000553         0.000000        0.000000
# 2        0.053163      0.002463         0.006206        0.000899
# 3        0.386640      0.006789         0.019901        0.001776
# 4        0.040335      0.000591         0.004879        0.000157
# 5        0.387630      0.007473         0.019501        0.001221
# 6        0.001549      0.000285         0.000000        0.000000
# 7        0.001580      0.000428         0.000000        0.000000
# 8        0.123754      0.006336         0.004646        0.000118
# 9        1.257781      0.011723         0.017535        0.000971
# 10       0.126591      0.002879         0.004784        0.000418
# 11       1.238840      0.015929         0.016821        0.002582
# 12       0.001672      0.000300         0.000000        0.000000
# ...

# %%
#age_input = float(input("Age= "))
#bmi_input = float(input("BMI= "))
#children_input = float(input("Children= "))
#sex_male_input = int(input("Male or Female 0 or 1: "))
#smoker_input = int(input("Smoker yes or no 0 or 1: "))

# %%
#Future_Predictions = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_input]])

# %%
#print("Future Predictions = {}".format(Future_Predictions))

# %%
import pickle

# %%
filename = "finalized_model_RFwtouttraintest.sav"

# %%
pickle.dump(grid, open(filename,'wb'))
