# %%
#importing pickle package to load the model

# %%
import pickle

# %%
#Loading the modelto make prediction

# %%
loaded_model = pickle.load(open("finalized_model_linear.sav", 'rb'))

# %%
#Giving input to the model and seeing the result

# %%
result = loaded_model.predict([[12]])
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Viewing the prediction below

# %%
result
# Out:
# array([[139100.52677552]])
